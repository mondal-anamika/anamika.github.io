# %%
import pandas as pd
import numpy as np

# %%
people_data_csv='people-1000.csv'
df=pd.read_csv(people_data_csv)

# %%
print(df)
# Out:
#       Index          User Id First Name Last Name     Sex  \
# 0         1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1         2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2         3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3         4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4         5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ...     ...              ...        ...       ...     ...
# 1002    678  F73c1acfEabbe77    Caitlin   Hoffman  Female
# 1003    679  CB7Bb6f8B855dD7      Peggy     Moore    Male
# 1004    680  fD9d0F38eFBa56B      Doris    Larsen  Female
# 1005    681  203e2beE6cc7d3b   Mercedes     Potts  Female
# 1006    682  7f1600A9e94BcDB      Craig     Duffy    Male
#
#                               Email               Phone Date of birth  \
# 0               pwarner@example.org        857.139.8239     1/27/2014
# 1     fergusonkatherine@example.net              -10395     7/26/1931
# ...

# %%
 df.head(10)
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# 5      6  aF75e6dDEBC5b66     Sherry  Caldwell    Male
# 6      7  efeb05c7Cc94EA3     Ernest   Hoffman    Male
# 7      8  fb1BF3FED57E9d7      Doris  Andersen    Male
# 8      9  421fAB9a3b98F30     Cheryl      Mays    Male
# 9     10  4A42Fe10dB717CB      Harry  Mitchell    Male
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239     1/27/2014
# 1  fergusonkatherine@example.net              -10395     7/26/1931
# 2            fhoward@example.org       (599)782-0605    11/25/2013
# 3          zjohnston@example.com               -7326    11/17/2012
# ...

# %%
print(df.to_string())
# Out:
#       Index          User Id   First Name    Last Name     Sex                           Email                   Phone Date of birth                                                    Job Title
# 0         1  8717bbf45cCDbEe       Shelia      Mahoney    Male             pwarner@example.org            857.139.8239     1/27/2014                                            Probation officer
# 1         2  3d5AD30A4cD38ed           Jo       Rivers  Female   fergusonkatherine@example.net                  -10395     7/26/1931                                                       Dancer
# 2         3  810Ce0F276Badec       Sheryl       Lowery  Female             fhoward@example.org           (599)782-0605    11/25/2013                                                         Copy
# 3         4  BF2a889C00f0cE1      Whitney       Hooper    Male           zjohnston@example.com                   -7326    11/17/2012                                     Counselling psychologist
# ...

# %%
df.tail(10)
# Out:
#       Index          User Id First Name Last Name     Sex  \
# 997     998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998     999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999    1000  8b756f6231DDC6e        Lee      Tran  Female
# 1000     12  86cCc6417942b4B       Sara      Huff    Male
# 1001    944  0bec75Ebba75267     Johnny   Elliott    Male
# 1002    678  F73c1acfEabbe77    Caitlin   Hoffman  Female
# 1003    679  CB7Bb6f8B855dD7      Peggy     Moore    Male
# 1004    680  fD9d0F38eFBa56B      Doris    Larsen  Female
# 1005    681  203e2beE6cc7d3b   Mercedes     Potts  Female
# 1006    682  7f1600A9e94BcDB      Craig     Duffy    Male
#
#                               Email                  Phone Date of birth  \
# 997          georgechan@example.org  +1-750-774-4128x33265     5/13/1918
# 998             wanda04@example.net          (915)292-2254     8/31/1971
# 999         deannablack@example.org     079.752.5424x67259     1/24/1947
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1007 non-null   int64
#  1   User Id        1007 non-null   object
#  2   First Name     1007 non-null   object
#  3   Last Name      1007 non-null   object
#  4   Sex            1007 non-null   object
#  5   Email          1005 non-null   object
#  6   Phone          1006 non-null   object
#  7   Date of birth  1007 non-null   object
#  8   Job Title      1005 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.9+ KB

# %%
df.duplicated().value_counts()
# Out:
# False    1000
# True        7
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    1000
# Name: count, dtype: int64

# %%
df.isnull().value_counts()
# Out:
# Index  User Id  First Name  Last Name  Sex    Email  Phone  Date of birth  Job Title
# False  False    False       False      False  False  False  False          False        995
#                                                                            True           2
#                                               True   False  False          False          2
#                                               False  True   False          False          1
# Name: count, dtype: int64

# %%
df['Email'].fillna("Not Submitted",inplace=True)

# %%
df['Email'].isnull().value_counts()
# Out:
# Email
# False    1000
# Name: count, dtype: int64

# %%
df['Phone'].isnull().value_counts()
# Out:
# Phone
# False    999
# True       1
# Name: count, dtype: int64

# %%
df[df['Phone'].isnull()]
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 387    388  Fc86a2288ebfdAd    Leonard   Parsons  Female
#
#                            Email Phone Date of birth            Job Title
# 387  christinaconner@example.com   NaN    09-07-1942  Seismic interpreter

# %%
df['Phone'].dropna(inplace=True)

# %%
df['Phone'].isnull().value_counts()
# Out:
# Phone
# False    999
# True       1
# Name: count, dtype: int64

# %%
df.dropna(subset=['Phone'],inplace=True)

# %%
df['Phone'].isnull().value_counts()
# Out:
# Phone
# False    999
# Name: count, dtype: int64

# %%
df[df['Job Title'].isnull()]
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 384    385  6455dAf38a33E73      Tommy     Combs    Male
# 392    393  d500353D059Efd9      Bryce      Ball  Female
#
#                          Email                  Phone Date of birth Job Title
# 384  figueroaalice@example.net           204-364-8124    11/19/2020       NaN
# 392      chelsey42@example.net  001-463-956-2617x8538    04-07-2018       NaN

# %%
df['Job Title'].isnull().value_counts()
# Out:
# Job Title
# False    997
# True       2
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Index            0
# User Id          0
# First Name       0
# Last Name        0
# Sex              0
# Email            0
# Phone            0
# Date of birth    0
# Job Title        2
# dtype: int64

# %%
df['Job Title'].fillna("Not Assigned",inplace=True)

# %%
df['Job Title'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          999 non-null    int64
#  1   User Id        999 non-null    object
#  2   First Name     999 non-null    object
#  3   Last Name      999 non-null    object
#  4   Sex            999 non-null    object
#  5   Email          999 non-null    object
#  6   Phone          999 non-null    object
#  7   Date of birth  999 non-null    object
#  8   Job Title      999 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 78.0+ KB

# %%
df['Job Title'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Job Title'>
